# %%
import pandas as pd

doctor_df = pd.read_csv('./전문의 현황.csv')
doctor_df
# Out:
#      시도별(1)   2008   2009   2010   2011   2012   2013   2014   2015   2016  \
# 0    시도별(1)     의사     의사     의사     의사     의사     의사     의사     의사     의사
# 1    시도별(1)    전문의    전문의    전문의    전문의    전문의    전문의    전문의    전문의    전문의
# 2         계  56028  58857  58722  64461  67574  70609  73110  75550  78282
# 3     서울특별시  15316  16200  16102  17816  18667  19423  19953  20361  21040
# 4     부산광역시   4379   4568   4698   5167   5369   5631   5822   6021   6196
# 5     대구광역시   3236   3404   3370   3634   3814   3941   4023   4174   4350
# 6     인천광역시   2419   2537   2511   2797   2951   3142   3347   3548   3686
# 7     광주광역시   1945   1990   2024   2225   2351   2451   2572   2686   2785
# 8     대전광역시   2000   2101   2136   2248   2395   2477   2566   2647   2731
# 9     울산광역시   1030   1073   1055   1163   1211   1252   1298   1380   1442
# 10  세종특별자치시      -      -      -      -     72     82    110    147    164
# ...

# %%
import pandas as pd

doctor_df = pd.read_csv('./total doctor.csv')
doctor_df
# Out:
#       행정구역별                              2014              2014.1  \
# 0     행정구역별  인구 천명당 의료기관 종사 의사수<br>(A÷B×1000)  의료기관 종사 의사수<br>(A)
# 1        전국                               2.6              134646
# 2     서울특별시                               3.8               38625
# 3     부산광역시                               3.0               10458
# 4     대구광역시                               3.0                7360
# 5     인천광역시                               2.1                6075
# 6     광주광역시                               3.2                4740
# 7     대전광역시                               3.1                4762
# 8     울산광역시                               2.0                2372
# 9   세종특별자치시                               1.3                 208
# 10      경기도                               2.1               25826
# 11  강원특별자치도                               2.3                3548
# 12     충청북도                               2.1                3299
# ...
